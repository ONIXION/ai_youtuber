# %% [markdown]
# # Youtube Data APIのアクセストークンを取得する

# %%
import requests
from dotenv import load_dotenv
load_dotenv()
import os
client_id = os.getenv("CLIENT_ID")
client_secret = os.getenv("CLIENT_SECRET")
refresh_token = os.getenv("REFRESH_TOKEN")

# トークン取得用のURL
url = "https://www.googleapis.com/oauth2/v4/token"

# データを辞書形式で定義
data = {
    "client_id": client_id,
    "client_secret": client_secret,
    "refresh_token": refresh_token,
    "grant_type": "refresh_token"
}

# POSTリクエストを送信
response = requests.post(url, data=data)

# レスポンスを確認
if response.status_code == 200:
    access_token = response.json().get("access_token")
    print("Access Token:", access_token)
else:
    print("Error:", response.status_code, response.text)
# Out:
# Access Token: ya29.a0ARW5m764zoMUXtjzwkl5RHRYO_-7vkp-dPpN9sY3t5eSflQBujExB08OPpZC0Puhti-YKpRjEi1RTEBBU7eFMOWjSe42g1TXH87QxwJcLKkXBI0l3vXSXvof7CJ94N8D-Wy0LTkWI2S2B-E3i15N-BZ_9CxcWytQ064Y9BP8IgaCgYKAToSARESFQHGX2MiitsP5b0Qki9rvowUXUSYdw0177
