# %% [markdown]
# # Youtube Data APIのアクセストークンを取得する

# %%
import requests
from dotenv import load_dotenv
load_dotenv()
import os
client_id = os.getenv("CLIENT_ID")
client_secret = os.getenv("CLIENT_SECRET")
refresh_token = os.getenv("REFRESH_TOKEN")

# トークン取得用のURL
url = "https://www.googleapis.com/oauth2/v4/token"

# データを辞書形式で定義
data = {
    "client_id": client_id,
    "client_secret": client_secret,
    "refresh_token": refresh_token,
    "grant_type": "refresh_token"
}

# POSTリクエストを送信
response = requests.post(url, data=data)

# レスポンスを確認
if response.status_code == 200:
    access_token = response.json().get("access_token")
    print("Access Token:", access_token)
else:
    print("Error:", response.status_code, response.text)

# %%
from dotenv import load_dotenv
load_dotenv()
import os
import time
from googleapiclient.discovery import build # pip install google-api-python-client

video_url = "https://www.youtube.com/watch?v=Kd2VOrGvz7U"
video_id = video_url.split("v=")[1].split("&")[0]
# YouTube Data APIキー（ここに取得したAPIキーを記述）
YOUTUBE_API_KEY = os.getenv("YOUTUBE_API_KEY")
# YouTube APIクライアントの初期化
youtube = build('youtube', 'v3', developerKey=YOUTUBE_API_KEY)
response = youtube.videos().list(
    part='liveStreamingDetails',
    id=video_id
).execute()

items = response.get('items', [])
if not items:
    print(f"動画ID {video_id} のライブチャットが見つかりません。")
live_details = items[0].get('liveStreamingDetails', {})
live_chat_id = live_details.get('activeLiveChatId')

def get_live_chat_messages(live_chat_id):
    """
    ライブチャットIDを元にライブコメントを取得
    """
    response = youtube.liveChatMessages().list(
        liveChatId=live_chat_id,
        part='snippet,authorDetails'

    ).execute()

    return response.get('items', [])

coments = get_live_chat_messages(live_chat_id)
for message in coments:
    author = message['authorDetails']['displayName']
    text = message['snippet']['displayMessage']
    print(f"{author}: {text}")
# Out:
# 初雪: 初雪 just became a member!
# geregere: geregere just became a member!
# みたらし: みたらし gifted 10 Lamy Ch. 雪花ラミィ memberships
# Fall P38: ¥3,000 from Fall P38
# 雪見酒: 雪見酒 gifted 5 Lamy Ch. 雪花ラミィ memberships
# こみゅれす: こみゅれす gifted 5 Lamy Ch. 雪花ラミィ memberships
# リエル☃️🧪: リエル☃️🧪 gifted 5 Lamy Ch. 雪花ラミィ memberships
# みたらし: みたらし gifted 10 Lamy Ch. 雪花ラミィ memberships
# きくらげ⚔: 👏👏👏👏👏👏
# 綾杉ひぃろ: 👏👏👏👏👏
# 裕: おめでとう:_よろこびラミィ::_よろこびラミィ::_よろこびラミィ:
# ぽんすけ太郎⚔️ボンレス公: おめでとー
# とっとこ🐾よっすぃ〜【白銀聖騎士団の乗り物】: 👏👏👏👏👏👏
# いずみ: 👏👏👏👏👏👏
# ユウヤニキ: :_よろこびラミィ::_よろこびラミィ::_よろこびラミィ:
# つむさか: 👏👏
# 氷の鍋: 👏👏👏👏👏👏👏
# メカコンドル: おお〜！
# 白い酒米【金雪】: 👏👏👏👏
# ベンベン: 👏🏻👏🏻👏🏻
# ゆーりんちー: 👏👏👏👏
# TF245: ラミィちゃんおめでとう！！👏👏👏👏👏👏
# Calculator: おめでとう！
# ウィ助【ウィース】: 草
# 003 REC: 👏👏👏👏👏👏👏
# つっつう: アニメすごいよかったよね
# kk kc: 少し　泣いた
# 吾輩は猫: おめでとう！
# クォーツ＠Tapioca【雪民】: 改めておめでとう！:_よろこびラミィ:
# 裸王: うんうん
# ウェッティー【白銀聖騎士団の税理士、ボンレス公】: 👏👏👏
# Hrtaka: ラミィちゃんおめでとう〜
# ﾖｰｼﾞﾛｰ!: :washhands::washhands::washhands::washhands::washhands::washhands::washhands::washhands:
# ちい: おめでとう:_びっくりまーく:
# セモヴェンティーノ: おめでとぉぉぉぉー！！！
# ジャーロ: :_よろこびラミィ::_よろこびラミィ::_よろこびラミィ:
# 漢梅サワー: ピンポンｗ
# かずちょん。: 放送見た
# しましま: よかぅたー！！！
# しがないカラス: おめでとう！！
# スットボケー【失った林檎】: 地上波デビューおめでとう
# コワカロッゾ: 👏👏👏👏👏
# メリー: おめでとう！！
# かずんだ⚔️ボンレス公(役職:みちのくの団員): 👏👏👏👏
# Matsu: 見たよおおお
# わにわに: 👏👏👏👏👏
# アリス・バーンストライク: おめでとう！
# ミミック: おめでとう！！！！！
# Shih aun: 👏👏👏👏👏👏👏
# 白狼: それ見たｗ
# かうかう博士: おめでとう！
# Mon　モン: おめでとう!
# サノ: 👏👏👏👏👏
# こらさわ: :_かなしみラミィ::_かなしみラミィ::_かなしみラミィ:
# hiro gissy: 「少し泣く」
# エスユーエムアール ⚔️ [ボンレス公]: ですね
# しゃラー: 👏👏👏👏👏
# でぜふ02: おめでとうー！
# Octo: 👏👏👏👏
# くらんくらん341【雪民】: :_かなしみラミィ::_雪民さん01::_よしよし::_よしよし:
# ぺーぺーぼーず: 👏👏👏👏
# アストワール十 反逆の暗黒騎士アスト 十 【雪民】: 👏👏👏👏👏
# ろん: 👏👏👏👏👏
# アミノ: :_だいそうげん:
# もふから: 👏👏👏👏👏
# ちゅん⚔️ 【グレートポメラマン】: 👏👏👏👏👏
# mm ss: アニメOPおめでとう！
# ささささむ: 👏👏👏👏👏
# B J: おめでとう！
# こうこや: おめでとー
# くりーむきゃんでぃちゃん: 改めておめでとう
# じょる: あれね〜
# るぷるぷ: ピンポンｗ
# Jyoji   : 👏👏👏👏
# エスティ: 👏👏
# もかー: 👏👏👏👏👏
# 白⚔️団[ボンレス公]⛄民: 👏👏👏👏👏
# geroaji: ピンポンかな？ｗ
# 涼介(りょうへい)⚔️: ラミィちゃんおめでとう！
# nyui matsuoka: :washhands::washhands::washhands::washhands::washhands::washhands:
# 鱈ればぁ: おめでとうー
# ヒロキ: 👏👏👏👏👏👏
